# %%
pip install wordcloud
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.2/539.2 kB 18.0 MB/s eta 0:00:00
# ...
#   WARNING: The script wordcloud_cli is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request # this packager works with URLs and to download data

text = urllib.request.urlopen("https://raw.githubusercontent.com/MartenJa/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/class_work/test").read().decode("utf-8") # making this file into "readable format", so that the code coldalso read it

text[0:50]

from wordcloud import WordCloud


WordCloud().generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
wc =WordCloud().generate_from_text("And not just some cute toadstool or gnome’s bed")
img =wc.to_image()
img.show()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
WordCloud(stopwords=["and", "the", "play", "but", "brain", "of", "that", "it", "to", "a", "by"], background_color="pink").generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
from PIL import Image #Import the image class from the PIL library. This library can use to work with images
import urllib.request #This can use to download files from the internet

img = urllib.request.urlretrieve("https://drive.google.com/uc?export=download&id=1axqWQpZOo_baYKv3XkI7ohtBtK956mX2", "image1.png")

Image.open("image1.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=739x731>

# %%
import urllib.request
from PIL import Image
import numpy as np #This one we need to handle image mask

text = urllib.request.urlopen("https://drive.google.com/uc?export=download&id=1-9dlbi6ZQ9hE1gyvNzI87oBQGXG7vC6m").read().decode("utf-8")

img = urllib.request.urlretrieve("https://drive.google.com/uc?export=download&id=1axqWQpZOo_baYKv3XkI7ohtBtK956mX2", "image1.png")

WordCloud(mask=np.array(Image.open("image1.png")), background_color="pink").generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=739x731>

# %%
text = urllib.request.urlopen("https://raw.githubusercontent.com/MartenJa/dt-2025-data-visualisation/refs/heads/codespace-jubilant-orbit-gr97595599x39g76/notebooks/class_work/test").read().decode("utf-8")

img = urllib.request.urlretrieve("https://drive.google.com/uc?export=download&id=1axqWQpZOo_baYKv3XkI7ohtBtK956mX2", "image1.png")

stopwords_list = urllib.request.urlopen("https://gist.githubusercontent.com/sebleier/554280/raw/7e0e4a1ce04c2bb7bd41089c9821dbcf6d0c786c/NLTK's%2520list%2520of%2520english%2520stopwords").read().decode("utf-8").split("\n")
# The file that we are downloadingcontains 1 word per 1 line. When python takes it, it'll become 1 long string (this\nand\nthat). So split("\n") will cut the text every time it sees a new line 

WordCloud(mask=np.array(Image.open("image1.png")), background_color="pink").generate_from_text(text).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=739x731>

# %%
def color_function(word, font_size, position, orientation, random = None, **additional_args): #def color_function(...): This creates a function named color_function
    if len(word) < 4: #If the word has fewer than 4 letters, then the color  is green. If or more that 4, then blue.
        return "green"
    return "blue"

WordCloud().generate_from_text(text).recolor(color_func=color_function).to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>
